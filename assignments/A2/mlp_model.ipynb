# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc

# Typings
from numpy import ndarray
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Input
from tensorflow.keras.optimizers import Adam
from keras.src.callbacks import EarlyStopping
from tensorflow.python.keras.callbacks import History
from sklearn.preprocessing import StandardScaler
# Out:
# WARNING:tensorflow:From C:\Users\kaano\PycharmProjects\bim459-assignments\.venv\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
dataset_path: str = "../../data/assignment2/HeartDiseaseDataset_small.csv"

df = pd.read_csv(dataset_path)

X: ndarray = df.drop("HeartDisease", axis=1).to_numpy()
Y: ndarray = df["HeartDisease"].to_numpy()

X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.4, random_state=42)

X_val, X_test, Y_val, Y_test = train_test_split(X_test, Y_test, test_size=0.5, random_state=42)

# Train: 60%, Test: 20%, Validation: 20%

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_val = scaler.transform(X_val)
X_test = scaler.transform(X_test)


print("Input Shape: ", X_train.shape)
print("Output Shape: ", Y_train.shape)

input_shape = X_train.shape[1]
# Out:
# Input Shape:  (550, 6)
# Output Shape:  (550,)

# %%
mlp_model = Sequential([
    Input(shape=(input_shape,)),
    Dense(64, activation='leaky_relu'),
    Dense(32, activation='leaky_relu'),
    Dense(1, activation='sigmoid')
])

optimizer: Adam = Adam(learning_rate=0.0019)

early_stop: EarlyStopping  = EarlyStopping(
    monitor='val_loss',
    patience=20,
    min_delta= 0.0001,
    restore_best_weights=True
)


mlp_model.compile(optimizer=optimizer,
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\kaano\PycharmProjects\bim459-assignments\.venv\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.

# %%
history_mlp = mlp_model.fit(X_train, Y_train,
                        validation_data=(X_val, Y_val),
                        epochs=38,
                        batch_size=32,
                        #callbacks=[early_stop]
                            )
# Out:
# Epoch 1/38
# WARNING:tensorflow:From C:\Users\kaano\PycharmProjects\bim459-assignments\.venv\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\kaano\PycharmProjects\bim459-assignments\.venv\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 18/18 [==============================] - 2s 18ms/step - loss: 0.6000 - accuracy: 0.7055 - val_loss: 0.5040 - val_accuracy: 0.7554
# Epoch 2/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4962 - accuracy: 0.7509 - val_loss: 0.4805 - val_accuracy: 0.7826
# Epoch 3/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4797 - accuracy: 0.7691 - val_loss: 0.4790 - val_accuracy: 0.7554
# Epoch 4/38
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4744 - accuracy: 0.7873 - val_loss: 0.4968 - val_accuracy: 0.7772
# Epoch 5/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4704 - accuracy: 0.7836 - val_loss: 0.4845 - val_accuracy: 0.7609
# Epoch 6/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4622 - accuracy: 0.7927 - val_loss: 0.4845 - val_accuracy: 0.7500
# Epoch 7/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4603 - accuracy: 0.7945 - val_loss: 0.4811 - val_accuracy: 0.7717
# Epoch 8/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4574 - accuracy: 0.8000 - val_loss: 0.4802 - val_accuracy: 0.7663
# Epoch 9/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4550 - accuracy: 0.7945 - val_loss: 0.4905 - val_accuracy: 0.7609
# Epoch 10/38
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4505 - accuracy: 0.8000 - val_loss: 0.4743 - val_accuracy: 0.7609
# Epoch 11/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4492 - accuracy: 0.8055 - val_loss: 0.4801 - val_accuracy: 0.7663
# Epoch 12/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4469 - accuracy: 0.8091 - val_loss: 0.4873 - val_accuracy: 0.7663
# Epoch 13/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4432 - accuracy: 0.8018 - val_loss: 0.4774 - val_accuracy: 0.7609
# Epoch 14/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4427 - accuracy: 0.8055 - val_loss: 0.4849 - val_accuracy: 0.7609
# Epoch 15/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4412 - accuracy: 0.8018 - val_loss: 0.4793 - val_accuracy: 0.7609
# Epoch 16/38
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4383 - accuracy: 0.8036 - val_loss: 0.4760 - val_accuracy: 0.7609
# Epoch 17/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4370 - accuracy: 0.8073 - val_loss: 0.4820 - val_accuracy: 0.7663
# Epoch 18/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4361 - accuracy: 0.8036 - val_loss: 0.4781 - val_accuracy: 0.7554
# Epoch 19/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4356 - accuracy: 0.8182 - val_loss: 0.4736 - val_accuracy: 0.7663
# Epoch 20/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4354 - accuracy: 0.8091 - val_loss: 0.4909 - val_accuracy: 0.7609
# Epoch 21/38
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4349 - accuracy: 0.8091 - val_loss: 0.4729 - val_accuracy: 0.7717
# Epoch 22/38
# 18/18 [==============================] - 0s 6ms/step - loss: 0.4316 - accuracy: 0.8127 - val_loss: 0.4724 - val_accuracy: 0.7446
# Epoch 23/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4308 - accuracy: 0.8127 - val_loss: 0.4691 - val_accuracy: 0.7554
# Epoch 24/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4275 - accuracy: 0.8127 - val_loss: 0.4747 - val_accuracy: 0.7609
# Epoch 25/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4271 - accuracy: 0.8109 - val_loss: 0.4742 - val_accuracy: 0.7663
# Epoch 26/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4269 - accuracy: 0.8145 - val_loss: 0.4780 - val_accuracy: 0.7554
# Epoch 27/38
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4271 - accuracy: 0.8164 - val_loss: 0.4811 - val_accuracy: 0.7609
# Epoch 28/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4299 - accuracy: 0.8073 - val_loss: 0.4983 - val_accuracy: 0.7500
# Epoch 29/38
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4227 - accuracy: 0.8145 - val_loss: 0.4658 - val_accuracy: 0.7663
# Epoch 30/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4230 - accuracy: 0.8182 - val_loss: 0.4865 - val_accuracy: 0.7609
# Epoch 31/38
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4192 - accuracy: 0.8127 - val_loss: 0.4843 - val_accuracy: 0.7554
# Epoch 32/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4178 - accuracy: 0.8091 - val_loss: 0.4880 - val_accuracy: 0.7391
# Epoch 33/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4180 - accuracy: 0.8182 - val_loss: 0.4789 - val_accuracy: 0.7554
# Epoch 34/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4181 - accuracy: 0.8200 - val_loss: 0.4852 - val_accuracy: 0.7609
# Epoch 35/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4166 - accuracy: 0.8164 - val_loss: 0.4865 - val_accuracy: 0.7500
# Epoch 36/38
# 18/18 [==============================] - 0s 4ms/step - loss: 0.4140 - accuracy: 0.8145 - val_loss: 0.4861 - val_accuracy: 0.7554
# Epoch 37/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4155 - accuracy: 0.8127 - val_loss: 0.4765 - val_accuracy: 0.7554
# Epoch 38/38
# 18/18 [==============================] - 0s 5ms/step - loss: 0.4105 - accuracy: 0.8182 - val_loss: 0.4860 - val_accuracy: 0.7609

# %%
Y_pred_prob = mlp_model.predict(X_test)
Y_pred = (Y_pred_prob > 0.5).astype(int)

cm = confusion_matrix(Y_test, Y_pred)

fpr, tpr, _ = roc_curve(Y_test, Y_pred_prob)
roc_auc = auc(fpr, tpr)

fig, axs = plt.subplots(2, 2, figsize=(14, 10))

axs[0, 0].plot(history_mlp.history['loss'], label='Training Loss')
axs[0, 0].plot(history_mlp.history['val_loss'], label='Validation Loss')
axs[0, 0].set_title('Loss')
axs[0, 0].set_xlabel('Epochs')
axs[0, 0].set_ylabel('Loss')
axs[0, 0].legend()
axs[0, 0].grid(True)

axs[0, 1].plot(history_mlp.history['accuracy'], label='Training Accuracy')
axs[0, 1].plot(history_mlp.history['val_accuracy'], label='Validation Accuracy')
axs[0, 1].set_title('Accuracy vs Epochs')
axs[0, 1].set_xlabel('Epochs')
axs[0, 1].set_ylabel('Accuracy')
axs[0, 1].legend()
axs[0, 1].grid(True)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(ax=axs[1, 0], colorbar=False)
axs[1, 0].set_title("Confusion Matrix")

axs[1, 1].plot(fpr, tpr, label=f'AUC = {roc_auc:.2f}')
axs[1, 1].plot([0, 1], [0, 1], linestyle='--')
axs[1, 1].set_title('ROC Curve')
axs[1, 1].set_xlabel('False Positive Rate')
axs[1, 1].set_ylabel('True Positive Rate')
axs[1, 1].legend()
axs[1, 1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# 6/6 [==============================] - 0s 3ms/step

# %%
from logistic_model import history

acc_log = history.history['accuracy']
val_acc_log = history.history['val_accuracy']
loss_log = history.history['loss']
val_loss_log = history.history['val_loss']

acc_mlp = history_mlp.history['accuracy']
val_acc_mlp = history_mlp.history['val_accuracy']
loss_mlp = history_mlp.history['loss']
val_loss_mlp = history_mlp.history['val_loss']

epochs_log = range(1, len(acc_log) + 1)
epochs_mlp = range(1, len(acc_mlp) + 1)

fig, axs = plt.subplots(1, 2, figsize=(12, 5))

axs[0].plot(epochs_log, acc_log, label='Logistic Regression Train Accuracy', color='green')
axs[0].plot(epochs_log, val_acc_log, label='Logistic Regression Validation Accuracy', color='blue', linestyle='--')
axs[0].plot(epochs_mlp, acc_mlp, label='MLP Classifier Train Accuracy', color='red')
axs[0].plot(epochs_mlp, val_acc_mlp, label='MLP Classifier Validation Accuracy', color='orange', linestyle='--')
axs[0].set_title('Accuracy Comparison')
axs[0].set_xlabel('Epochs')
axs[0].set_ylabel('Accuracy')
axs[0].grid(True)
axs[0].legend()

axs[1].plot(epochs_log, loss_log, label='Logistic Regression Train Loss', color='green')
axs[1].plot(epochs_log, val_loss_log, label='Logistic Regression Validation Loss', color='blue', linestyle='--')
axs[1].plot(epochs_mlp, loss_mlp, label='MLP Classifier Train Loss', color='red')
axs[1].plot(epochs_mlp, val_loss_mlp, label='MLP Classifier Validation Loss', color='orange', linestyle='--')
axs[1].set_title('Loss Comparison')
axs[1].set_xlabel('Epochs')
axs[1].set_ylabel('Loss')
axs[1].grid(True)
axs[1].legend()

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from logistic_model import history
#       3 acc_log = history.history['accuracy']
#       4 val_acc_log = history.history['val_accuracy']
#
# ModuleNotFoundError: No module named 'logistic_model'
